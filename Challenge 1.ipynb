# %%
% matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
Y = Image.open('mystery_number_scrambled.jpg')
implot = plt.imshow(Y)

# %%
print Y.size
# Out:
# (592, 480)

# %%
Y_arr = np.asarray(Y)
Y_f = Y_arr.flatten()
print len(Y_f)
# Out:
# 284160

# %%
with open('shuffle_indices.txt', 'r') as f:
    index = f.read().splitlines()
    
print len(index)
# Out:
# 284160

# %%
X = np.zeros(len(index))
for i in range(len(index)):
    X[int(index[i])] = Y_f[i]

X = X.reshape(480, 592)
plt.imshow(X)
